# 0    0.538252  0.669443  0.278676  0.728431  0.406420  0.348379  0
# 1    0.407634  0.700072  0.979357  0.926512  0.746281  0.995472  1
# 2    0.465950  0.098758  0.040910  0.497999  0.495231  0.994617  0
# 3    0.569612  0.486317  0.943641  0.673497  0.504340  0.877119  0
# 4    0.141827  0.006494  0.746912  0.456158  0.628018  0.331238  0
# ..        ...       ...       ...       ...       ...       ... ..
# 995  0.132985  0.375401  0.955779  0.343473  0.277009  0.951977  1
# 996  0.193799  0.261444  0.473607  0.337034  0.932036  0.426709  0
# 997  0.141579  0.732311  0.905478  0.989674  0.863524  0.219444  0
# 998  0.727363  0.478657  0.468958  0.235936  0.830236  0.214529  0
# 999  0.294380  0.759270  0.166443  0.107606  0.186413  0.186763  1
#
# [1000 rows x 21 columns]

# %%
from sklearn.linear_model import LogisticRegression

# %%
df_train.describe()
# Out:
#                x1          x2          x3          x4          x5          x6  \
# count  200.000000  200.000000  200.000000  200.000000  200.000000  200.000000
# mean     0.498041    0.499974    0.486934    0.503925    0.486312    0.509621
# std      0.290505    0.299964    0.280694    0.275815    0.279856    0.291739
# min      0.012829    0.001831    0.013058    0.005242    0.016070    0.001900
# 25%      0.261033    0.219562    0.262693    0.291828    0.248142    0.262402
# 50%      0.457044    0.525654    0.474085    0.550489    0.447308    0.489458
# 75%      0.764940    0.755385    0.717483    0.719201    0.744278    0.756452
# max      0.987306    0.993529    0.996391    0.997734    0.997851    0.996152
#
#                x7          x8          x9         x10  ...         x12  \
# count  200.000000  200.000000  200.000000  200.000000  ...  200.000000
# mean     0.521303    0.474187    0.496608    0.495999  ...    0.515182
# std      0.298430    0.282637    0.299148    0.296324  ...    0.295530
# min      0.002696    0.001918    0.008000    0.001610  ...    0.002918
# 25%      0.251959    0.225290    0.236972    0.220512  ...    0.256892
# 50%      0.518531    0.463557    0.473829    0.508048  ...    0.523639
# 75%      0.791040    0.726464    0.758722    0.745760  ...    0.760459
# max      0.984323    0.996079    0.996467    0.980638  ...    0.998434
#
#               x13         x14         x15         x16         x17         x18  \
# count  200.000000  200.000000  200.000000  200.000000  200.000000  200.000000
# mean     0.490169    0.484779    0.508922    0.494168    0.523979    0.538038
# std      0.291759    0.280981    0.295937    0.277480    0.286457    0.289818
# min      0.001329    0.007932    0.010142    0.005772    0.000164    0.004205
# 25%      0.242523    0.240292    0.223012    0.261301    0.304945    0.296068
# 50%      0.505778    0.478916    0.516871    0.500100    0.524810    0.559933
# 75%      0.747383    0.733077    0.775362    0.715559    0.771494    0.794618
# max      0.988843    0.988624    0.994804    0.999942    0.994148    0.997363
#
#               x19         x20           y
# count  200.000000  200.000000  200.000000
# mean     0.481174    0.506464    0.485000
# std      0.300823    0.303508    0.501029
# min      0.002349    0.000832    0.000000
# 25%      0.238197    0.258552    0.000000
# 50%      0.466439    0.496910    0.000000
# 75%      0.717173    0.760962    1.000000
# max      0.998004    0.999834    1.000000
#
# [8 rows x 21 columns]

# %%
X=df_train.loc[:,'x1':'x20']

# %%
y=df_train.loc[:,'y']

# %%
sum(y)
# Out:
# 97

# %%
len(y)
# Out:
# 200

# %%
clf=LogisticRegression().fit(X,y)

# %%
clf.score(X,y)
# Out:
# 0.9

# %%
X_test=df_test.loc[:,'x1':'x20']
y_test=df_test.loc[:,'y']

# %%
clf.score(X_test,y_test)
# Out:
# 0.832

# %%
from sklearn.metrics import roc_curve

# %%
y_pred=clf.predict(X_test)
# y_pred=y_pred[:,1]

# %%
fpr,tpr,_=roc_curve(y_test,y_pred)

# %%
from matplotlib import pyplot as plt
plt.plot(fpr, tpr, marker='.', label='Logistic')

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83       491
#            1       0.85      0.81      0.83       509
#
#     accuracy                           0.83      1000
#    macro avg       0.83      0.83      0.83      1000
# weighted avg       0.83      0.83      0.83      1000

# %% [markdown]
# ## K-Fold Cross Validation

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ### Logistic Rgression

# %%
from sklearn.linear_model import LogisticRegression
X=df_train.loc[:,'x1':'x20']
y=df_train.loc[:,'y']
clf=LogisticRegression()
scores = cross_val_score(clf, X, y, cv=5)

# %%
scores
# Out:
# array([0.75 , 0.825, 0.85 , 0.825, 0.9  ])

# %%
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# Accuracy: 0.83 (+/- 0.10)

# %%
clf=LogisticRegression().fit(X,y)
X_test=df_test.loc[:,'x1':'x20']
y_test=df_test.loc[:,'y']
clf.score(X_test,y_test)
# Out:
# 0.832

# %%
from sklearn.linear_model import LogisticRegressionCV
clf = LogisticRegressionCV(cv=5, random_state=0).fit(X, y)
clf.score(X_test,y_test)
# Out:
# 0.834

# %%
import numpy as np

def sigmoid(z):
    return 1/(1 + np.exp(-z))

# %%
from sklearn.metrics import classification_report, accuracy_score

from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X,y)
predicitons = model.predict(X)
value = {}
for thrs in range(30,70):
    thrs = thrs/100
    pred_bool = (sigmoid(predicitons)>thrs)
    pred = np.multiply(pred_bool, 1)
    value[thrs] = 1 - accuracy_score(y, pred)

# %%
value
x = {k: v for k, v in sorted(value.items(), key=lambda item: item[1])}

# %%
list(x.keys())[0]
# Out:
# 0.63

# %%
# x

# %%
import matplotlib.pyplot as plt

# %%
x_=list(value.keys())
y_=list(value.values())
plt.plot(x_,y_)

# %%
x_
# Out:
# [0.63,
#  0.62,
#  0.64,
#  0.61,
#  0.65,
#  0.66,
#  0.6,
#  0.59,
#  0.67,
#  0.58,
#  0.68,
#  0.57,
#  0.56,
#  0.69,
#  0.55,
#  0.54,
#  0.53,
#  0.52,
#  0.51,
#  0.5,
#  0.48,
#  0.49,
#  0.47,
#  0.46,
#  0.45,
#  0.43,
#  0.44,
#  0.4,
#  0.41,
#  0.42,
#  0.3,
#  0.31,
#  0.32,
#  0.33,
#  0.34,
#  0.35,
#  0.36,
#  0.37,
#  0.38,
#  0.39]

# %%
from sklearn.model_selection import KFold # Import KFold from model selection
kf = KFold(n_splits=5)  # Taking no of splits=5
arr=[]
arr1=[]
i=0
for train, test in kf.split(X):  # Running loop on 5 validation datasets
    X_train1=X.loc[train] #validation training data
    y_train1=y.loc[train] # validation training label
    X_test1=X.loc[test]  # validation test data
    y_test1=y.loc[test]  # validation test label
    model = LinearRegression() 
    model.fit(X_train1,y_train1) # model fitting
    predicitons = model.predict(X_test1) # predicting on validation test data 
    value = {} # making a dictionary named value which take key as threshold value and value as misclassification error
    for thrs in range(30,70): #looping threshold value in range(30,70)
        thrs = thrs/100
        pred_bool = (sigmoid(predicitons)>thrs) # if sigmoid function greater than threshold will give oputput 1 else 0
        pred = np.multiply(pred_bool, 1)
        value[thrs] = 1 - accuracy_score(y_test1, pred)
    x = {k: v for k, v in sorted(value.items(), key=lambda item: item[1])}
    if i==0:# for 1st validation storing value_0
        value_0=value 
    elif i==1: # for 2nd validation
        value_1=value
    elif i==2: # for 3rd validation
        value_2=value
    elif i==3: # for 4th validation
        value_3=value
    elif i==4: # for 5th validation
        value_4=value
    arr.append(list(x.keys())[0])
    arr1.append(list(x.values())[0])
    i+=1

plt.figure(figsize=(10,6)) #Plotting figure
x_=list(value_0.keys())
y_=list(value_0.values())
plt.plot(x_,y_,label='Val1') # PLotting line graph where X-axis is threshold value
x_=list(value_1.keys())       # and Y-Axis is misclassification error
y_=list(value_1.values())     # on 5 Validation give 5 different line plots.
plt.plot(x_,y_,label='Val2')
x_=list(value_2.keys())
y_=list(value_2.values())
plt.plot(x_,y_,label='Val3')
x_=list(value_3.keys())
y_=list(value_3.values())
plt.plot(x_,y_,label='Val4')
x_=list(value_4.keys())
y_=list(value_4.values())
plt.plot(x_,y_,label='Val5')
plt.xlabel('Threshold Probability')
plt.ylabel('Misclassification Error')
plt.title('Linear Regression with Sigmoid Function optimization')
plt.legend()
# Out:
# [0.64, 0.59, 0.64, 0.61, 0.62]

# %%
sum(arr)/5
# Out:
# 0.62

# %%
sum(arr1)/5
# Out:
# 0.12499999999999997

# %%
model = LinearRegression()
model.fit(X,y)
predicitons = model.predict(X_test)
1- accuracy_score(y_test,np.multiply(sigmoid(model.predict(X_test)) > 0.62,1))
# Out:
# 0.15700000000000003

# %%
# plt.figure(figsize=(10,6))
# x_=list(value_0.keys())
# y_=list(value_0.values())
# plt.plot(x_,y_,label='Val1')
# x_=list(value_1.keys())
# y_=list(value_1.values())
# plt.plot(x_,y_,label='Val2')
# x_=list(value_2.keys())
# y_=list(value_2.values())
# plt.plot(x_,y_,label='Val3')
# x_=list(value_3.keys())
# y_=list(value_3.values())
# plt.plot(x_,y_,label='Val4')
# x_=list(value_4.keys())
# y_=list(value_4.values())
# plt.plot(x_,y_,label='Val5')
# plt.xlabel('Threshold Probability')
# plt.ylabel('Misclassification Error')
# plt.title('Linear Regression with Sigmoid Function optimization')
# plt.legend()

# %% [markdown]
# ### Linear SVC

# %%
from sklearn import svm
from sklearn.metrics import accuracy_score
clf = svm.SVC(kernel='linear', C=1)
clf.fit(X,y)
y_pred=clf.predict(X)
accuracy_score(y,y_pred)
# Out:
# 0.895

# %%
clf=svm.SVC(kernel='linear', C=0.1).fit(X,y)
1-clf.score(X,y)
# Out:
# 0.13

# %%
clf=svm.SVC(kernel='linear', C=0.1).fit(X,y)
1-clf.score(X_test,y_test)
# Out:
# 0.18400000000000005

# %%
clf=svm.SVC(kernel='linear', C=1).fit(X,y)
1-clf.score(X,y)
# Out:
# 0.10499999999999998

# %%
clf=svm.SVC(kernel='linear', C=1).fit(X,y)
1-clf.score(X_test,y_test)
# Out:
# 0.16800000000000004

# %%
clf=svm.SVC(kernel='linear', C=10).fit(X,y)
1-clf.score(X,y)
# Out:
# 0.09999999999999998

# %%
clf=svm.SVC(kernel='linear', C=10).fit(X,y)
1-clf.score(X_test,y_test)
# Out:
# 0.16200000000000003

# %%
clf=svm.SVC(kernel='linear', C=100).fit(X,y)
1-clf.score(X,y)
# Out:
# 0.09999999999999998

# %%
clf=svm.SVC(kernel='linear', C=100).fit(X,y)
1-clf.score(X_test,y_test)
# Out:
# 0.17300000000000004

# %%
# plt.figure(figsize=(10,16))
# labels=[0.1,1,10,100]

# x = np.arange(len(labels))  # the label locations
# width = 0.2  # the width of the bars
# plt.bar()
# set width of bar 
barWidth = 0.25
bars1=[1,2,3,4]
fig = plt.subplots(figsize =(12, 8)) 
   
# set height of bar 
train_misclassification_score=[0.13,.1049,.0999,.0999]
test_misclassification_score=[.184,.168,.162,.173]
   
# Set position of bar on X axis 
br1 = np.arange(len(bars1)) 
br2 = [x + barWidth for x in br1] 
   
# Make the plot 
plt.bar(br1, train_misclassification_score, color ='r', width = barWidth, 
        edgecolor ='grey', label ='train_misclassification_score') 
plt.bar(br2, test_misclassification_score, color ='g', width = barWidth, 
        edgecolor ='grey', label ='test_misclassification_score') 

   
# Adding Xticks  
plt.xlabel('Hyperparameter C') 
plt.ylabel('Misclassification Score', fontweight ='bold') 
plt.xticks([r + barWidth for r in range(len(train_misclassification_score))], 
           ['0.1', '1', '10', '100']) 
plt.legend()   
plt.show()

# %%
from sklearn import svm
clf = svm.SVC(kernel='linear', C=10)
scores = cross_val_score(clf, X, y, cv=5)
scores
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# Accuracy: 0.84 (+/- 0.11)

# %%
from sklearn import svm
clf = svm.SVC(kernel='linear', C=100)
scores = cross_val_score(clf, X, y, cv=5)
scores
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# Accuracy: 0.83 (+/- 0.12)

# %%
clf=svm.SVC(kernel='linear', C=0.1).fit(X,y)
clf.score(X_test,y_test)
# Out:
# 0.816

# %%
clf=svm.SVC(kernel='linear', C=1).fit(X,y)
clf.score(X_test,y_test)
# Out:
# 0.832

# %%
clf=svm.SVC(kernel='linear', C=10).fit(X,y)
clf.score(X_test,y_test)
# Out:
# 0.838

# %%
clf=svm.SVC(kernel='linear', C=100).fit(X,y)
clf.score(X_test,y_test)
# Out:
# 0.827

# %% [markdown]
# ### KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
clf=KNeighborsClassifier(n_neighbors=3)
scores = cross_val_score(clf, X, y, cv=5)
scores
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# Accuracy: 0.65 (+/- 0.10)

# %%
from sklearn.neighbors import KNeighborsClassifier
clf=KNeighborsClassifier(n_neighbors=5)
scores = cross_val_score(clf, X, y, cv=5)
scores
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# Accuracy: 0.66 (+/- 0.12)

# %%
from sklearn.neighbors import KNeighborsClassifier
clf=KNeighborsClassifier(n_neighbors=10)
scores = cross_val_score(clf, X, y, cv=5)
scores
print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# Accuracy: 0.69 (+/- 0.21)

# %%
clf=KNeighborsClassifier(n_neighbors=1).fit(X,y)
clf.score(X,y)
# Out:
# 1.0

# %%
clf=KNeighborsClassifier(n_neighbors=3).fit(X,y)
clf.score(X,y)
# Out:
# 0.85

# %%
clf=KNeighborsClassifier(n_neighbors=5).fit(X,y)
clf.score(X,y)
# Out:
# 0.77

# %%
clf=KNeighborsClassifier(n_neighbors=10).fit(X,y)
clf.score(X,y)
# Out:
# 0.765

# %%
clf=KNeighborsClassifier(n_neighbors=1).fit(X,y)
clf.score(X_test,y_test)
# Out:
# 0.61

# %%
clf=KNeighborsClassifier(n_neighbors=3).fit(X,y)
clf.score(X_test,y_test)
# Out:
# 0.662

# %%
clf=KNeighborsClassifier(n_neighbors=5).fit(X,y)
clf.score(X_test,y_test)
# Out:
# 0.664

# %%
clf=KNeighborsClassifier(n_neighbors=10).fit(X,y)
clf.score(X_test,y_test)
# Out:
# 0.708

# %% [markdown]
# ### Decision Tree

# %%
import matplotlib.pyplot as plt

# %%
df_train.columns
# Out:
# Index(['x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9', 'x10', 'x11',
#        'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19', 'x20', 'y'],
#       dtype='object')

# %%
df_train
# Out:
#            x1        x2        x3        x4        x5        x6        x7  \
# 0    0.832164  0.734772  0.626653  0.238078  0.338718  0.364629  0.533504
# 1    0.434020  0.054741  0.316852  0.229558  0.714776  0.185191  0.288082
# 2    0.167477  0.627895  0.379868  0.834608  0.286843  0.146932  0.745286
# 3    0.917487  0.349867  0.026223  0.904135  0.189632  0.068428  0.424099
# 4    0.262515  0.128063  0.684576  0.452624  0.384034  0.032154  0.912727
# ..        ...       ...       ...       ...       ...       ...       ...
# 195  0.875564  0.447265  0.647535  0.075995  0.815324  0.642850  0.819127
# 196  0.215458  0.472076  0.927122  0.330321  0.079936  0.607314  0.650436
# 197  0.492485  0.652036  0.160117  0.748103  0.190880  0.427767  0.713974
# 198  0.259781  0.337814  0.780454  0.019218  0.734124  0.678968  0.109626
# 199  0.046412  0.668283  0.888986  0.957727  0.315173  0.622399  0.878224
#
#            x8        x9       x10  ...       x12       x13       x14  \
# 0    0.484752  0.673383  0.394322  ...  0.813944  0.686857  0.442066
# 1    0.040074  0.588396  0.671829  ...  0.862059  0.590721  0.084614
# 2    0.063496  0.872345  0.137706  ...  0.238914  0.606350  0.906995
# 3    0.097569  0.669446  0.264504  ...  0.998434  0.676528  0.436011
# 4    0.058140  0.946419  0.172531  ...  0.852647  0.534161  0.569734
# ..        ...       ...       ...  ...       ...       ...       ...
# 195  0.822828  0.877649  0.153677  ...  0.703536  0.162772  0.091870
# 196  0.989894  0.880038  0.972501  ...  0.172467  0.574111  0.032684
# 197  0.343303  0.247126  0.758726  ...  0.544055  0.492855  0.704248
# 198  0.528298  0.075438  0.739172  ...  0.337964  0.525577  0.305988
# 199  0.105448  0.185266  0.135391  ...  0.194171  0.362015  0.028167
#
#           x15       x16       x17       x18       x19       x20  y
# 0    0.208592  0.846246  0.416390  0.681197  0.415797  0.351630  1
# 1    0.890323  0.501312  0.084612  0.751885  0.696986  0.664690  1
# 2    0.722755  0.957155  0.772042  0.942410  0.250488  0.401736  0
# 3    0.510557  0.254132  0.638738  0.262307  0.917623  0.252353  0
# 4    0.293528  0.380042  0.304119  0.465901  0.748553  0.740586  1
# ..        ...       ...       ...       ...       ...       ... ..
# 195  0.488601  0.909432  0.860282  0.191033  0.243161  0.391432  1
# 196  0.436811  0.604341  0.950769  0.599006  0.715343  0.014482  0
# 197  0.520730  0.418953  0.102939  0.923285  0.006273  0.948847  0
# 198  0.052472  0.045109  0.523355  0.652448  0.494828  0.307445  0
# 199  0.120725  0.778780  0.524203  0.258422  0.317324  0.104363  1
#
# [200 rows x 21 columns]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
data=df_train.loc[:,'x1':'y']

# %%
#Scale the data
scaler = StandardScaler()
scaler.fit(data)
scaled = scaler.transform(data)

#Obtain principal components
pca = PCA().fit(scaled)

pc = pca.transform(scaled)
pc1 = pc[:,0]
pc2 = pc[:,1]

#Plot principal components
plt.figure(figsize=(10,10))

colour = ['#ff2121' if y == 1 else '#2176ff' for y in data['y']]
plt.scatter(pc1,pc2 ,c=colour,edgecolors='#000000')

# %%
var = pca.explained_variance_[0:20] #percentage of variance explained
labels = ['PC1','PC2','PC3','PC4','PC5','PC6','PC7','PC8','PC9','PC10','PC11','PC12','PC13','PC14','PC15','PC16','PC17','PC18','PC19','PC20']

plt.figure(figsize=(15,7))
plt.bar(labels,var,)
plt.xlabel('Pricipal Component')
plt.ylabel('Proportion of Variance Explained')
# Out:
# Text(0, 0.5, 'Proportion of Variance Explained')

# %%
#
